# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Import the os module for working with directories
import os

# Change the current working directory
os.chdir("/content/drive/MyDrive/Timi_overweight_bindea2013")

# Print the current working directory to verify the change
print(os.getcwd())
# Out:
# /content/drive/MyDrive/Timi_overweight_bindea2013

# %%
#set working directory
setwd("/content/drive/MyDrive/Timi_overweight_bindea2013")

# %% [markdown]
# # Installation and libraries

# %% [markdown]
# Installation and libraries

# %%
# Code for overweight dataset
library(survival)
library(dplyr)
install.packages("doParallel")
library(doParallel)
library(foreach)
library(ggplot2)
install.packages("circlize")
library(circlize)
library(RColorBrewer)

# Install devtools from CRAN if not already installed.

if(!require(devtools)){

install.packages("devtools")

}

# Install TimiGP R package from GitHub:

# https://github.com/CSkylarL/TimiGP

devtools::install_github("CSkylarL/TimiGP")
library(TimiGP)
library(grid)
library(grDevices)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘foreach’, ‘iterators’
#
#
# Loading required package: foreach
#
# Loading required package: iterators
#
# Loading required package: parallel
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘GlobalOptions’, ‘shape’
#
#
# ========================================
# circlize version 0.4.16
# CRAN page: https://cran.r-project.org/package=circlize
# Github page: https://github.com/jokergoo/circlize
# Documentation: https://jokergoo.github.io/circlize_book/book/
#
# If you use it in published research, please cite:
# Gu, Z. circlize implements and enhances circular visualization
#   in R. Bioinformatics 2014.
#
# This message can be suppressed by:
#   suppressPackageStartupMessages(library(circlize))
# ========================================
#
#
# Loading required package: devtools
#
# Loading required package: usethis
#
# Downloading GitHub repo CSkylarL/TimiGP@HEAD
# ── R CMD build ─────────────────────────────────────────────────────────────────
# * checking for file ‘/tmp/Rtmp3KwvKE/remotes217c5ce47dc7/CSkylarL-TimiGP-9a527dd/DESCRIPTION’ ... OK
# * preparing ‘TimiGP’:
# * checking DESCRIPTION meta-information ... OK
# * checking for LF line-endings in source and make files and shell scripts
# * checking for empty or unneeded directories
# * looking to see if a ‘data/datalist’ file should be added
# * building ‘TimiGP_1.3.0.tar.gz’
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("gridExtra")
library(gridExtra)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
#
# Attaching package: ‘gridExtra’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     combine

# %% [markdown]
# # Set up Data (Choose the gene TimiGp gene set)

# %%
#manually edit event to binary 0 and 1 in excel and imprt the csv back: column name 1st vacant, 2nd event, 3rd: time, deleted all NA kept vacnat as cells
SKCM06rna <- read.csv("/content/drive/MyDrive/Timi_overweight_bindea2013/processed_PDAC_over_weight_TPM.csv", check.names = FALSE)
SKCM06info <- read.csv("/content/drive/MyDrive/Timi_overweight_bindea2013/overweight_clin_edit.csv")
geneset <- read.csv("/content/drive/MyDrive/Timi_overweight_bindea2013/CellType_Bindea2013_cancer.csv") (Choose data set here)
#geneset <- read.csv("/content/drive/MyDrive/Timi over weight zang2021/CellType_Zheng2021_Tcell.csv")
#geneset <- read.csv("/content/drive/MyDrive/timigp overweight llm22/CellType_newman2015_LM22.csv")

marker <- unique(geneset$Gene)

# %%
# Set the first column as row names and remove it from the data frame
SKCM06rna <- SKCM06rna[!is.na(SKCM06rna[,1]), ]
rownames(SKCM06rna) <- SKCM06rna[,1]
SKCM06rna <- SKCM06rna[,-1]

# Set the first column as row names and remove it from the data frame
SKCM06info <- SKCM06info[!is.na(SKCM06info[,1]), ]
rownames(SKCM06info) <- SKCM06info[,1]
SKCM06info <- SKCM06info[,-1]

head(SKCM06rna)
dim(SKCM06rna)

head(SKCM06info)
head(geneset)
# Out:
#          C3L-00589 C3N-00302 C3L-02118 C3L-01703 C3N-00518 C3N-00511 C3N-01715
# A1BG       0.1586    0.3497    0.2957    0.4879    0.0746    0.1486    0.2201
# A1BG-AS1   0.6059    0.8291    1.1877    1.1567    1.1052    1.2332    0.6846
# A1CF       3.2226    2.9420    1.7171    4.0470    2.2832    2.2991    0.3265
# A2M      455.2124  402.6404  333.5841  734.2546  359.4156  327.2430  208.8962
# A2M-AS1    3.0607    4.0168    3.7883    8.4392    5.4389    5.9625    8.1155
# A2ML1      0.2561    4.8210   18.2595    1.0339   12.1516    0.3560    0.1998
#          C3L-01036 C3L-04495 C3N-03666 ⋯ C3L-03635 C3N-02295 C3N-03426
# A1BG       0.2285    0.2047    0.3639  ⋯   0.2348    0.7506    0.2427
# A1BG-AS1   1.7065    1.3515    1.3863  ⋯   0.8116    1.8714    0.4794
# A1CF       4.7965    4.4928    1.9591  ⋯   1.9797    7.6961    6.5191
# A2M      334.1018  553.5721  535.6444  ⋯ 523.6287  939.8271  198.9155
# A2M-AS1    4.2781    8.5272    3.8784  ⋯   5.5730   14.2554    4.1703
# A2ML1      0.8812    1.5359    0.7553  ⋯   0.4920    0.9113    0.5425
#          C3N-02998 C3N-01012 C3L-03388 C3N-02768 C3L-03394 C3L-01037 C3L-02897
# A1BG       0.1578    0.0676    0.2260    0.0346    0.6928    0.2075    0.2712
# A1BG-AS1   0.8414    0.7744    0.4821    0.7180    1.9994    1.0284    1.2169
# A1CF       0.5420    4.1282    1.1293    3.1569    8.1788    3.9823    3.4044
# A2M      556.1689  359.7180  323.5981  423.8010  594.9709  370.0487  557.9081
# A2M-AS1   17.8163    5.1803    4.1691    2.6296   18.3063    3.0703    5.4661
# A2ML1      0.2094    0.1196    0.6314    5.4068    0.5723   30.3040    6.9720
# [1] 40894    58
#           event time
# C3L-00017 0      426
# C3L-00102 1      249
# C3L-00589 0     1752
# C3L-00599 1     1352
# C3L-00622 1     1041
# C3L-00819 1      603
#   CellType Gene  Dataset
# 1 aDC      CCL1  Bindea2013
# 2 aDC      EBI3  Bindea2013
# 3 aDC      INDO  Bindea2013
# 4 aDC      OAS3  Bindea2013
# 5 aDC      LAMP3 Bindea2013
# 6 B        IGKC  Bindea2013

# %%
info <- TimiCheckEvent(SKCM06info)

rna <- TimiPrePropress(marker = marker, rna = SKCM06rna, cohort = rownames(info), log = TRUE, GMNorm=TRUE)

mps <- TimiGenePair(rna=rna, cont=FALSE)


# Run the TimiCOX function

res <- TimiCOX( mps = mps,

                info = info,

                p.adj = "fdr",

                parallel = T,

                core = 15)
# Out:
# 1 individuals were filtered out due to NAs or time <= 0
#
# 0 markers with low expressions were filtered out
#
# Generating marker pairs
#
# The default is to capture logical relation
#
# 0 marker pairs were filtered out
#
# 101926 marker pairs were produced
#
# Enable parallel computing.
#
# ------------- Calculating -------------
#
# Please be patient.
#
# The computation time may be increased if there are a larger number of cell type markers.
#
# The direction of 50132 marker pairs were reversed

# %% [markdown]
# # Set P value or Q value cut offs

# %%
# Extract the 'mps' and 'cox_res' objects from the 'res' result
mps <- res$mps
cox_res <- res$cox_res

# Count the number of marker pairs with Adjusted P-value (PV) less than 0.01
sum(cox_res$PV < 0.01)

# Calculate the percentage of significant marker pairs relative to the total number of marker pairs
round(sum(cox_res$PV < 0.01) / nrow(cox_res) * 100, 2)

# Set up a variable to define the condition for selecting marker pairs based on the Adjusted P-value
GPcondition <- "PV"

# Set up a variable to define the cutoff value for the Adjusted P-value
GPcutoff <- 0.01
# Out:
# [1] 6033
# [1] 5.92

# %% [markdown]
# If P value is selected run this code other wise skip this code. Run to see top 1% & 5% genes from p=<0.01 markers

# %%
# Sort cox_res by P-value (PV) in ascending order to select the top 5% and 1% of significant markers
top_5_percent_count <- ceiling(0.05 * nrow(cox_res))
top_1_percent_count <- ceiling(0.01 * nrow(cox_res))

top_5_percent_markers <- cox_res[order(cox_res$PV), ][1:top_5_percent_count, ]
top_1_percent_markers <- cox_res[order(cox_res$PV), ][1:top_1_percent_count, ]

# Calculate and print the number of markers for the top 5%
print(paste("Number of markers in the top 5%:", top_5_percent_count))

# Calculate and print the number of markers for the top 1%
print(paste("Number of markers in the top 1%:", top_1_percent_count))
# Out:
# [1] "Number of markers in the top 5%: 5097"
# [1] "Number of markers in the top 1%: 1020"

# %% [markdown]
# # Top 5% data

# %% [markdown]
# Run permutations for top 5% data

# %%
GP <- rownames(top_5_percent_markers)[which(top_5_percent_markers[,GPcondition] < GPcutoff)]

background <- TimiBG(marker.pair = row.names(top_5_percent_markers))

cell_pair <- TimiCellPair(geneset = geneset, core = 8)

res <- TimiEnrich( gene = GP,

                   background = background,

                   geneset = cell_pair,

                   p.adj = "BH",

                   core = 15,

                   pair=TRUE)

# Count the number of marker pairs with an Adjusted P-value less than 0.05

sum(res$Adjust.P.Value < 0.01)

# Calculate the percentage of cell-cell interaction defined by the above condition and the cutoff

round(sum(res$Adjust.P.Value < 0.01)/nrow(res) * 100, 2) # Returns 11.69

# Set up a variable to define the condition for cell-cell interaction based on the Adjusted P-value.

CIcondition <- "Adjust.P.Value"

# Set up a variable to define the cutoff value for the Adjusted P-value.

CIcutoff <- 0.05

# CI represents Cell-cell Interaction

res <- TimiPermFDR( resdata = res,

                    geneset = geneset,

                    gene = GP,

                    background = background,

                    niter = 100,

                    core = 15)
# Out:
# 10194 Background Pairs were generated from given 5097 pairs
# [1] 80
# [1] 17.32
# --------------- Run 100 permutations. Please be patient ---------------
#
# Permeutation#1: Different / Total markers: 544/545
#
# Permeutation#2: Different / Total markers: 543/545
#
# Permeutation#3: Different / Total markers: 543/545
#
# Permeutation#4: Different / Total markers: 545/545
#
# Permeutation#5: Different / Total markers: 544/545
#
# Permeutation#6: Different / Total markers: 544/545
#
# Permeutation#7: Different / Total markers: 545/545
#
# Permeutation#8: Different / Total markers: 544/545
#
# Permeutation#9: Different / Total markers: 544/545
#
# Permeutation#10: Different / Total markers: 545/545
#
# Permeutation#11: Different / Total markers: 543/545
#
# Permeutation#12: Different / Total markers: 545/545
#
# Permeutation#13: Different / Total markers: 543/545
#
# Permeutation#14: Different / Total markers: 545/545
#
# Permeutation#15: Different / Total markers: 545/545
#
# Permeutation#16: Different / Total markers: 542/545
#
# Permeutation#17: Different / Total markers: 543/545
#
# Permeutation#18: Different / Total markers: 544/545
#
# Permeutation#19: Different / Total markers: 545/545
#
# Permeutation#20: Different / Total markers: 544/545
#
# Permeutation#21: Different / Total markers: 543/545
#
# Permeutation#22: Different / Total markers: 543/545
#
# Permeutation#23: Different / Total markers: 545/545
#
# Permeutation#24: Different / Total markers: 545/545
#
# Permeutation#25: Different / Total markers: 544/545
#
# Permeutation#26: Different / Total markers: 545/545
#
# Permeutation#27: Different / Total markers: 545/545
#
# Permeutation#28: Different / Total markers: 545/545
#
# Permeutation#29: Different / Total markers: 545/545
#
# Permeutation#30: Different / Total markers: 544/545
#
# Permeutation#31: Different / Total markers: 545/545
#
# Permeutation#32: Different / Total markers: 544/545
#
# Permeutation#33: Different / Total markers: 544/545
#
# Permeutation#34: Different / Total markers: 544/545
#
# Permeutation#35: Different / Total markers: 544/545
#
# Permeutation#36: Different / Total markers: 545/545
#
# Permeutation#37: Different / Total markers: 545/545
#
# Permeutation#38: Different / Total markers: 545/545
#
# Permeutation#39: Different / Total markers: 545/545
#
# Permeutation#40: Different / Total markers: 545/545
#
# Permeutation#41: Different / Total markers: 544/545
#
# Permeutation#42: Different / Total markers: 544/545
#
# Permeutation#43: Different / Total markers: 543/545
#
# Permeutation#44: Different / Total markers: 544/545
#
# Permeutation#45: Different / Total markers: 544/545
#
# Permeutation#46: Different / Total markers: 544/545
#
# Permeutation#47: Different / Total markers: 545/545
#
# Permeutation#48: Different / Total markers: 544/545
#
# Permeutation#49: Different / Total markers: 542/545
#
# Permeutation#50: Different / Total markers: 544/545
#
# Permeutation#51: Different / Total markers: 543/545
#
# Permeutation#52: Different / Total markers: 543/545
#
# Permeutation#53: Different / Total markers: 544/545
#
# Permeutation#54: Different / Total markers: 544/545
#
# Permeutation#55: Different / Total markers: 542/545
#
# Permeutation#56: Different / Total markers: 543/545
#
# Permeutation#57: Different / Total markers: 544/545
#
# Permeutation#58: Different / Total markers: 545/545
#
# Permeutation#59: Different / Total markers: 544/545
#
# Permeutation#60: Different / Total markers: 545/545
#
# Permeutation#61: Different / Total markers: 543/545
#
# Permeutation#62: Different / Total markers: 544/545
#
# Permeutation#63: Different / Total markers: 545/545
#
# Permeutation#64: Different / Total markers: 545/545
#
# Permeutation#65: Different / Total markers: 545/545
#
# Permeutation#66: Different / Total markers: 544/545
#
# Permeutation#67: Different / Total markers: 544/545
#
# Permeutation#68: Different / Total markers: 544/545
#
# Permeutation#69: Different / Total markers: 545/545
#
# Permeutation#70: Different / Total markers: 544/545
#
# Permeutation#71: Different / Total markers: 544/545
#
# Permeutation#72: Different / Total markers: 545/545
#
# Permeutation#73: Different / Total markers: 544/545
#
# Permeutation#74: Different / Total markers: 545/545
#
# Permeutation#75: Different / Total markers: 543/545
#
# Permeutation#76: Different / Total markers: 545/545
#
# Permeutation#77: Different / Total markers: 545/545
#
# Permeutation#78: Different / Total markers: 544/545
#
# Permeutation#79: Different / Total markers: 544/545
#
# Permeutation#80: Different / Total markers: 544/545
#
# Permeutation#81: Different / Total markers: 544/545
#
# Permeutation#82: Different / Total markers: 544/545
#
# Permeutation#83: Different / Total markers: 545/545
#
# Permeutation#84: Different / Total markers: 545/545
#
# Permeutation#85: Different / Total markers: 543/545
#
# Permeutation#86: Different / Total markers: 544/545
#
# Permeutation#87: Different / Total markers: 544/545
#
# Permeutation#88: Different / Total markers: 545/545
#
# Permeutation#89: Different / Total markers: 544/545
#
# Permeutation#90: Different / Total markers: 543/545
#
# Permeutation#91: Different / Total markers: 545/545
#
# Permeutation#92: Different / Total markers: 542/545
#
# Permeutation#93: Different / Total markers: 544/545
#
# Permeutation#94: Different / Total markers: 545/545
#
# Permeutation#95: Different / Total markers: 544/545
#
# Permeutation#96: Different / Total markers: 541/545
#
# Permeutation#97: Different / Total markers: 544/545
#
# Permeutation#98: Different / Total markers: 545/545
#
# Permeutation#99: Different / Total markers: 545/545
#
# Permeutation#100: Different / Total markers: 543/545
#
# --------------- Permutation done. Calculating FDR ---------------
#
# The permutation has been succesfully perfomed. Please check the new column "Permutation.FDR"

# %% [markdown]
# TimiDotPlot

# %%
library(ggplot2)

# Function to create TimiDotplot in a specific format
save_timidotplot <- function(filename, width = 10, height = 8, res = 300,
                             resdata, select, condition, cutoff,
                             color_by = "Adjust.P.Value", color_limits = c(0, 0.01)) {
  # Open the appropriate device based on file extension
  switch(tools::file_ext(filename),
         "svg" = svg(filename, width = width, height = height),
         "tiff" = tiff(filename, width = width, height = height, units = "in", res = res),
         "pdf" = pdf(filename, width = width, height = height))

  # Create the TimiDotplot
  tryCatch({
    plot <- TimiDotplot(resdata = resdata,
                        select = select,
                        condition = condition,
                        cutoff = cutoff)

    # Modify the plot to set color and limits
    plot <- plot +
      scale_color_gradient(low = "blue", high = "red",
                           limits = color_limits,
                           oob = scales::squish) +
      labs(color = color_by)

    # Print the modified plot
    print(plot)

  }, error = function(e) {
    message("Error in TimiDotplot or plot modification: ", e$message)
  })

  # Close the device
  dev.off()
}

# Save in SVG format
save_timidotplot("timidotplot_Top5percent.svg",
                 resdata = res,
                 select = c(1:10),
                 condition = CIcondition,
                 cutoff = CIcutoff)

# Save in TIFF format
save_timidotplot("timidotplot_Top5percent.tiff",
                 resdata = res,
                 select = c(1:10),
                 condition = CIcondition,
                 cutoff = CIcutoff)

# Save in PDF format
save_timidotplot("timidotplot_Top5percent.pdf",
                 resdata = res,
                 select = c(1:10),
                 condition = CIcondition,
                 cutoff = CIcutoff)
# Out:
# The color for dotplot is Adjust.P.Value
#
# The color bar limits for dotplot is 0.05
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# pdf
#   2
# The color for dotplot is Adjust.P.Value
#
# The color bar limits for dotplot is 0.05
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# pdf
#   2
# The color for dotplot is Adjust.P.Value
#
# The color bar limits for dotplot is 0.05
#
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# pdf
#   2

# %% [markdown]
# Construct Cell Network

# %%
CellNET <- TimiCellNetwork( resdata = res,

                            select = NULL,

                            dataset = "Bindea2013_Cancer",

                            group = NULL,

                            geneset = NULL,

                            condition = CIcondition,

                            cutoff = CIcutoff,

                            export = TRUE,

                            path = "./")

# Display the first few rows of the 'network' component in the CellNET list

head(CellNET$network)

# Display the first few rows of the 'node' component in the CellNET object

head(CellNET$node)

# Display the first few rows of the 'edge' component in the NET object

head(CellNET$edge)
# Out:
# Using cell-cell interactions(Adjust.P.Value < 0.05)
#     Source     Interaction Target
# 195 Eosinophil TimiGP      Neutrophil
# 198 Mast       TimiGP      Neutrophil
# 205 Tcm        TimiGP      Neutrophil
# 282 Mast       TimiGP      Tumor
# 191 B          TimiGP      Neutrophil
# 321 Eosinophil TimiGP      Th
#   Key           No.Markers Group
# 2 B             34         B Cell
# 3 CD56bright NK 11         NK Cell
# 4 CD56dim NK    15         NK Cell
# 5 CD8 T         37         T Cell
# 6 Cytotoxic     17         Cytotoxic Cell
# 7 DC             7         DC
#     Key                            Index Rank Cell.Interaction
# 195 Eosinophil (TimiGP) Neutrophil 1     1    Eosinophil_Neutrophil
# 198 Mast (TimiGP) Neutrophil       2     2    Mast_Neutrophil
# 205 Tcm (TimiGP) Neutrophil        3     3    Tcm_Neutrophil
# 282 Mast (TimiGP) Tumor            4     4    Mast_Tumor
# 191 B (TimiGP) Neutrophil          5     5    B_Neutrophil
# 321 Eosinophil (TimiGP) Th         6     6    Eosinophil_Th
#     Favorable.Cell.Type Unfavorable.Cell.Type No.Total.IMGP No.Shared.IMGP
# 195 Eosinophil          Neutrophil            132           129
# 198 Mast                Neutrophil            106           105
# 205 Tcm                 Neutrophil             70            70
# 282 Mast                Tumor                  59            59
# 191 B                   Neutrophil             67            65
# 321 Eosinophil          Th                     75            71
#     Enrichment.Ratio P.Value      Adjust.P.Value Permutation.FDR
# 195 1.955            3.082951e-35 1.424323e-32   0.000000000
# 198 1.981            7.531924e-31 1.739874e-28   0.000000000
# 205 2.000            6.586127e-22 1.014263e-19   0.006666667
# 282 2.000            1.451785e-18 1.676812e-16   0.017500000
# 191 1.940            1.259829e-17 1.164082e-15   0.022000000
# 321 1.893            2.701913e-17 2.080473e-15   0.020000000
#     Shared.IMGP
# 195 SMPD3_SLC25A37/ABHD2_CD93/ABHD2_FPR1/MYO15B_DYSF/SMPD3_FPR1/SMPD3_S100A12/ACACB_ALPL/SMPD3_SIGLEC5/SMPD3_DYSF/KBTBD11_FPR1/MYO15B_CD93/ACACB_CD93/SMPD3_ALPL/SMPD3_MME/CAT_CD93/KBTBD11_CD93/SMPD3_HPSE/SMPD3_LILRB2/ACACB_DYSF/SYNJ1_DYSF/SMPD3_PDE4B/KBTBD11_DYSF/MYO15B_FPR1/ABHD2_HPSE/MYO15B_PDE4B/SMPD3_G0S2/CAT_FPR1/SMPD3_SLC22A4/ACACB_PDE4B/SMPD3_FCAR/SMPD3_TNFRSF10C/MYO15B_LILRB2/MYO15B_ALPL/ABHD2_SIGLEC5/KBTBD11_MME/ABHD2_FCAR/ABHD2_CEACAM3/RCOR3_PDE4B/ACACB_CREB5/ABHD2_PDE4B/SMPD3_CEACAM3/KBTBD11_S100A12/SMPD3_CREB5/SMPD3_CD93/ABHD2_CSF3R/ABHD2_DYSF/ABHD2_G0S2/MYO15B_G0S2/EPN2_G0S2/GALC_DYSF/CAT_ALPL/IL5RA_DYSF/KBTBD11_BST1/ACACB_G0S2/CAT_DYSF/SMPD3_CSF3R/KBTBD11_ALPL/RRP12_G0S2/ACACB_CEACAM3/SYNJ1_G0S2/ABHD2_ALPL/KBTBD11_SLC22A4/KBTBD11_CSF3R/KBTBD11_G0S2/ABHD2_BST1/CYSLTR2_MME/CAT_PDE4B/MYO15B_FCAR/HES1_G0S2/SMPD3_CRISPLD2/HRH4_DYSF/ABHD2_LILRB2/SIAH1_CD93/HRH4_FPR1/CAT_CEACAM3/KBTBD11_TNFRSF10C/IL5RA_ALPL/ABHD2_MME/HRH4_PDE4B/RRP12_MME/KBTBD11_HPSE/CAT_G0S2/ACACB_SLC25A37/THBS4_CD93/IL5RA_G0S2/CAT_FCAR/KBTBD11_LILRB2/SYNJ1_CD93/KBTBD11_PDE4B/CAT_LILRB2/ABHD2_CRISPLD2/ACACB_FPR1/SIAH1_MME/ACACB_LILRB2/HRH4_LILRB2/ACACB_FCAR/HES1_MME/GALC_PDE4B/TIPARP_FPR1/LRP5L_G0S2/IL5RA_PDE4B/RCOR3_G0S2/SMPD3_FCGR3B/KBTBD11_FCAR/SYNJ1_MME/SMPD3_BST1/CAT_SIGLEC5/TIPARP_G0S2/ABHD2_TNFRSF10C/MYO15B_MME/ABHD2_CREB5/RCOR3_ALPL/MYO15B_HPSE/SIAH1_DYSF/MYO15B_CREB5/RCOR3_MME/HRH4_MME/CAT_SLC25A37/ABHD2_FCGR3B/RCOR3_CD93/ACACB_MME/CAT_S100A12/RCOR3_DYSF/GALC_ALPL/CCR3_G0S2/CYSLTR2_FPR1/SIAH1_G0S2/KBTBD11_CEACAM3/CAT_MME
# 198 MAOB_CD93/MAOB_ALPL/PPM1H_FPR1/MAOB_DYSF/MAOB_FPR1/PPM1H_ALPL/MAOB_CREB5/HPGD_DYSF/TPSAB1_CD93/MAOB_PDE4B/SLC18A2_CD93/PPM1H_CD93/TPSAB1_FPR1/CTSG_MME/TAL1_CD93/GATA2_G0S2/TPSB2_G0S2/SIGLEC6_CRISPLD2/TAL1_G0S2/CTSG_G0S2/TAL1_SLC25A37/TPSAB1_PDE4B/HPGD_FPR1/HPGD_FCAR/SLC24A3_FPR1/HDC_G0S2/NR0B1_G0S2/HPGD_G0S2/HPGD_CD93/MS4A2_PDE4B/SLC18A2_G0S2/HPGD_MME/MAOB_S100A12/TAL1_FCAR/PPM1H_LILRB2/PPM1H_MME/CEACAM8_MME/SIGLEC6_DYSF/MS4A2_CRISPLD2/PPM1H_DYSF/TAL1_PDE4B/TPSB2_FPR1/PPM1H_PDE4B/MAOB_G0S2/CMA1_MME/TPSAB1_G0S2/MS4A2_G0S2/CEACAM8_DYSF/MS4A2_DYSF/HPGD_SLC22A4/MAOB_LILRB2/HPGD_ALPL/MAOB_BST1/MAOB_MME/SIGLEC6_MME/CTSG_S100A12/HPGD_PDE4B/SIGLEC6_PDE4B/SLC18A2_MME/MAOB_CEACAM3/SIGLEC6_G0S2/PPM1H_CREB5/HPGD_S100A12/KIT_CREB5/TPSAB1_MME/MS4A2_FCAR/SLC18A2_FPR1/MAOB_SLC22A4/TPSAB1_FCAR/TAL1_MME/NR0B1_MME/CMA1_G0S2/HPGD_CEACAM3/PPM1H_SIGLEC5/MAOB_CRISPLD2/MS4A2_ALPL/HDC_PDE4B/TAL1_ALPL/PRG2_PDE4B/PTGS1_MME/KIT_ALPL/SLC24A3_MME/SLC18A2_PDE4B/ABCC4_MME/ADCYAP1_G0S2/KIT_G0S2/HPGD_LILRB2/TAL1_DYSF/SIGLEC6_CREB5/SIGLEC6_TNFRSF10C/HDC_MME/SIGLEC6_CEACAM3/PRG2_MME/MLPH_DYSF/CEACAM8_SLC25A37/CEACAM8_FPR1/TPSB2_CRISPLD2/MAOB_CSF3R/HPGD_CSF3R/CTSG_FPR1/MAOB_HPSE/HPGD_TNFRSF10C/CMA1_CD93/CEACAM8_FCAR/MPO_MME
# 205 CEP68_CD93/PCM1_G0S2/PSPC1_MME/CEP68_DYSF/MAP3K1_MME/POLR2J2_DYSF/TRAF3IP3_G0S2/INPP4B_G0S2/PCM1_PDE4B/POLR2J2_MME/RPP38_PDE4B/INPP4B_FPR1/MAP3K1_PDE4B/TXK_G0S2/INPP4B_CD93/PCM1_DYSF/CASP8_MME/TXK_PDE4B/FOXP1_DYSF/CASP8_PDE4B/RPP38_G0S2/KLF12_G0S2/NFATC3_MME/PSPC1_PDE4B/TRAF3IP3_FPR1/FOXP1_ALPL/CYLD_DYSF/SNRPN_PDE4B/NFATC3_DYSF/INPP4B_MME/POLR2J2_G0S2/NEFL_ALPL/NEFL_G0S2/SNRPN_MME/USP9Y_CD93/PHC3_CD93/RPP38_LILRB2/CEP68_PDE4B/REPS1_MME/PHC3_MME/RPP38_ALPL/STX16_MME/RPP38_MME/RPP38_CD93/SNRPN_G0S2/CEP68_G0S2/TRAF3IP3_MME/ATF7IP_G0S2/USP9Y_DYSF/POLR2J2_FCAR/NEFL_CREB5/FOXP1_MME/SNRPN_DYSF/USP9Y_MME/RPP38_FCAR/ATF7IP_MME/CREBZF_MME/TRAF3IP3_ALPL/PCM1_MME/NEFL_PDE4B/CLUAP1_DYSF/NFATC3_FCAR/CREBZF_G0S2/REPS1_G0S2/CEP68_ALPL/TXK_FCAR/CEP68_FCAR/PSPC1_FPR1/MAP3K1_G0S2/FOXP1_FPR1
# 282 KIT_S100A2/MS4A2_S100A2/MAOB_KRT13/TAL1_S100A2/PPM1H_ASPSCR1/MAOB_S100A2/MAOB_TEAD4/PPM1H_FKBP4/CTSG_S100A2/PPM1H_HOXA9/MAOB_IGF2/CEACAM8_S100A2/MAOB_ASPSCR1/CMA1_S100A2/CPA3_S100A2/MAOB_KRT5/SIGLEC6_INHBB/MAOB_MFAP2/MS4A2_KRT5/PPM1H_JAG2/CPA3_KRT5/SIGLEC6_S100A2/MAOB_DHRS2/HPGD_S100A2/MAOB_INHBB/MAOB_JAG2/HPGD_KRT5/MLPH_JAG2/SCG2_S100A2/NR0B1_S100A2/TAL1_FKBP4/PPM1H_S100A2/MLPH_S100A2/MAOB_SLC27A5/PPM1H_INHBB/MAOB_SLC1A5/MAOB_HOXA9/MAOB_VSNL1/ABCC4_S100A2/MAOB_ITGB4/GATA2_S100A2/SLC18A2_S100A2/MAOB_BMP4/HDC_S100A2/MAOB_RPP25/HPGD_FKBP4/SIGLEC6_KRT5/TPSB2_S100A2/ADCYAP1_S100A2/MPO_S100A2/PRG2_S100A2/MAOB_STRA6/PTGS1_S100A2/MAOB_RHOD/MAOB_FKBP4/MLPH_VSNL1/TPSB2_FKBP4/SLC24A3_S100A2/CTSG_DHRS2
# 191 BLNK_CEACAM3/BLNK_LILRB2/BLNK_ALPL/BLNK_MME/BLNK_CD93/SCN3A_DYSF/BLNK_FCAR/BLNK_G0S2/SPIB_G0S2/SCN3A_ALPL/BLNK_S100A12/GNG7_G0S2/GNG7_ALPL/SCN3A_CD93/GNG7_CD93/BLNK_HPSE/BLNK_PDE4B/BLK_FCAR/FAM30A_G0S2/BLNK_CREB5/CCR9_DYSF/SCN3A_PDE4B/MICAL3_MME/BLK_G0S2/SLC15A2_G0S2/TNFRSF17_G0S2/ABCB4_MME/BLK_PDE4B/BLNK_SIGLEC5/GNG7_DYSF/BLNK_FPR1/HLA-DOB_G0S2/DTNB_G0S2/CCR9_PDE4B/CCR9_LILRB2/BACH2_G0S2/SCN3A_FPR1/MS4A1_G0S2/BCL11A_G0S2/BLNK_DYSF/SCN3A_G0S2/HLA-DOB_ALPL/GNG7_FPR1/BLK_ALPL/GNG7_MME/CCR9_G0S2/SLC15A2_MME/IGHM_ALPL/BLK_FPR1/QRSL1_PDE4B/COCH_LILRB2/CCR9_CEACAM3/TCL1A_G0S2/CCR9_SLC25A37/BLNK_TNFRSF10C/GLDC_MME/BACH2_ALPL/GNG7_PDE4B/IGHA1_MME/QRSL1_G0S2/BLNK_CSF3R/SCN3A_MME/CD19_G0S2/ABCB4_G0S2/TNFRSF17_ALPL
# 321 SMPD3_ANP32B/SMPD3_ATF2/SMPD3_FRYL/SMPD3_UBE2L3/SMPD3_SLC25A12/MYO15B_SLC25A12/SMPD3_PPP2R5C/SMPD3_LRBA/ACACB_SLC25A12/SMPD3_DDX50/ABHD2_NUP107/SMPD3_NAP1L4/SMPD3_SEC24C/SMPD3_FAM111A/ABHD2_NAP1L4/SMPD3_RPA1/ABHD2_ANP32B/SMPD3_PHF10/ACACB_ANP32B/SMPD3_ASF1A/CAT_ATF2/ABHD2_RPA1/KBTBD11_ATF2/MYO15B_NAP1L4/ACACB_ATF2/KBTBD11_SLC25A12/SMPD3_NUP107/ABHD2_ATF2/KBTBD11_UBE2L3/SMPD3_CD28/SMPD3_BATF/MYO15B_RPA1/ACACB_PPP2R5C/CAT_SLC25A12/CAT_ANP32B/ACACB_RPA1/ACACB_FRYL/MYO15B_ATF2/ABHD2_PHF10/KBTBD11_GOLGA8A/ABHD2_FRYL/GALC_SLC25A12/KBTBD11_DDX50/IL5RA_SLC25A12/ABHD2_SLC25A12/MYO15B_FRYL/SMPD3_GOLGA8A/KBTBD11_NUP107/ABHD2_ICOS/KBTBD11_ASF1A/HRH4_ATF2/CAT_DDX50/MYO15B_ANP32B/MYO15B_NUP107/ACACB_NAP1L4/TKTL1_ANP32B/KBTBD11_PPP2R5C/CAT_PHF10/ACACB_DDX50/ACACB_SEC24C/SYNJ1_ANP32B/KBTBD11_PHF10/KBTBD11_NAP1L4/ABHD2_UBE2L3/ABHD2_DDX50/RCOR3_ANP32B/CAT_FRYL/KBTBD11_LRBA/ABHD2_SEC24C/CAT_PPP2R5C/ACACB_NUP107
#     Total.IMGP
# 195 IL5RA_ALPL/CAT_ALPL/ACACB_ALPL/GALC_ALPL/RCOR3_ALPL/KBTBD11_ALPL/ABHD2_ALPL/SMPD3_ALPL/MYO15B_ALPL/CAT_SIGLEC5/THBS1_SIGLEC5/ABHD2_SIGLEC5/SMPD3_SIGLEC5/CAT_CD93/ACACB_CD93/RCOR3_CD93/SYNJ1_CD93/THBS4_CD93/KBTBD11_CD93/ABHD2_CD93/SMPD3_CD93/MYO15B_CD93/SIAH1_CD93/TKTL1_MGAM/KBTBD11_CSF3R/ABHD2_CSF3R/SMPD3_CSF3R/HRH4_MME/CAT_MME/ACACB_MME/CYSLTR2_MME/RRP12_MME/RCOR3_MME/SYNJ1_MME/KBTBD11_MME/HES1_MME/ABHD2_MME/SMPD3_MME/MYO15B_MME/SIAH1_MME/ABHD2_FCGR3B/SMPD3_FCGR3B/IL5RA_DYSF/HRH4_DYSF/CAT_DYSF/ACACB_DYSF/GALC_DYSF/RCOR3_DYSF/SYNJ1_DYSF/KBTBD11_DYSF/ABHD2_DYSF/SMPD3_DYSF/MYO15B_DYSF/SIAH1_DYSF/CAT_FCAR/ACACB_FCAR/KBTBD11_FCAR/ABHD2_FCAR/SMPD3_FCAR/MYO15B_FCAR/CAT_CEACAM3/ACACB_CEACAM3/KBTBD11_CEACAM3/ABHD2_CEACAM3/SMPD3_CEACAM3/KBTBD11_HPSE/ABHD2_HPSE/SMPD3_HPSE/MYO15B_HPSE/ACACB_CREB5/ABHD2_CREB5/SMPD3_CREB5/MYO15B_CREB5/CAT_S100A12/KBTBD11_S100A12/SMPD3_S100A12/KBTBD11_TNFRSF10C/ABHD2_TNFRSF10C/SMPD3_TNFRSF10C/KBTBD11_SLC22A4/SMPD3_SLC22A4/CAT_SLC25A37/ACACB_SLC25A37/SMPD3_SLC25A37/TGIF1_BST1/KBTBD11_BST1/ABHD2_BST1/SMPD3_BST1/ABHD2_CRISPLD2/SMPD3_CRISPLD2/IL5RA_G0S2/CAT_G0S2/LRP5L_G0S2/CCR3_G0S2/ACACB_G0S2/RRP12_G0S2/RCOR3_G0S2/SYNJ1_G0S2/KBTBD11_G0S2/HES1_G0S2/ABHD2_G0S2/TIPARP_G0S2/SMPD3_G0S2/MYO15B_G0S2/EPN2_G0S2/SIAH1_G0S2/HRH4_FPR1/CAT_FPR1/ACACB_FPR1/CYSLTR2_FPR1/KBTBD11_FPR1/ABHD2_FPR1/TIPARP_FPR1/SMPD3_FPR1/MYO15B_FPR1/IL5RA_PDE4B/HRH4_PDE4B/CAT_PDE4B/ACACB_PDE4B/GALC_PDE4B/RCOR3_PDE4B/KBTBD11_PDE4B/ABHD2_PDE4B/SMPD3_PDE4B/MYO15B_PDE4B/HRH4_LILRB2/CAT_LILRB2/ACACB_LILRB2/KBTBD11_LILRB2/ABHD2_LILRB2/SMPD3_LILRB2/MYO15B_LILRB2
# 198 MS4A2_ALPL/PPM1H_ALPL/KIT_ALPL/TAL1_ALPL/MAOB_ALPL/HPGD_ALPL/PPM1H_SIGLEC5/TPSAB1_CD93/SLC18A2_CD93/CMA1_CD93/PPM1H_CD93/TAL1_CD93/MAOB_CD93/HPGD_CD93/MAOB_CSF3R/HPGD_CSF3R/SLC24A3_MME/PRG2_MME/CTSG_MME/TPSAB1_MME/SLC18A2_MME/HDC_MME/SIGLEC6_MME/CMA1_MME/MPO_MME/NR0B1_MME/PPM1H_MME/TAL1_MME/ABCC4_MME/PTGS1_MME/MAOB_MME/HPGD_MME/CEACAM8_MME/MLPH_DYSF/MS4A2_DYSF/SIGLEC6_DYSF/PPM1H_DYSF/TAL1_DYSF/MAOB_DYSF/HPGD_DYSF/CEACAM8_DYSF/TPSAB1_FCAR/MS4A2_FCAR/TAL1_FCAR/HPGD_FCAR/CEACAM8_FCAR/SIGLEC6_CEACAM3/MAOB_CEACAM3/HPGD_CEACAM3/MAOB_HPSE/SIGLEC6_CREB5/PPM1H_CREB5/KIT_CREB5/MAOB_CREB5/CTSG_S100A12/MAOB_S100A12/HPGD_S100A12/SIGLEC6_TNFRSF10C/HPGD_TNFRSF10C/MAOB_SLC22A4/HPGD_SLC22A4/TAL1_SLC25A37/CEACAM8_SLC25A37/PTGS1_BST1/MAOB_BST1/MS4A2_CRISPLD2/TPSB2_CRISPLD2/SIGLEC6_CRISPLD2/MAOB_CRISPLD2/ADCYAP1_G0S2/CTSG_G0S2/TPSAB1_G0S2/SLC18A2_G0S2/MS4A2_G0S2/TPSB2_G0S2/GATA2_G0S2/HDC_G0S2/SIGLEC6_G0S2/CMA1_G0S2/NR0B1_G0S2/KIT_G0S2/TAL1_G0S2/MAOB_G0S2/HPGD_G0S2/SLC24A3_FPR1/CTSG_FPR1/TPSAB1_FPR1/SLC18A2_FPR1/TPSB2_FPR1/PPM1H_FPR1/MAOB_FPR1/HPGD_FPR1/CEACAM8_FPR1/PRG2_PDE4B/TPSAB1_PDE4B/SLC18A2_PDE4B/MS4A2_PDE4B/HDC_PDE4B/SIGLEC6_PDE4B/PPM1H_PDE4B/TAL1_PDE4B/MAOB_PDE4B/HPGD_PDE4B/PPM1H_LILRB2/MAOB_LILRB2/HPGD_LILRB2
# 205 FOXP1_ALPL/TRAF3IP3_ALPL/NEFL_ALPL/CEP68_ALPL/RPP38_ALPL/USP9Y_CD93/PHC3_CD93/INPP4B_CD93/CEP68_CD93/RPP38_CD93/USP9Y_MME/FOXP1_MME/PCM1_MME/PHC3_MME/NFATC3_MME/ATF7IP_MME/REPS1_MME/PSPC1_MME/INPP4B_MME/CASP8_MME/SNRPN_MME/TRAF3IP3_MME/POLR2J2_MME/CREBZF_MME/MAP3K1_MME/STX16_MME/RPP38_MME/CLUAP1_DYSF/USP9Y_DYSF/FOXP1_DYSF/PCM1_DYSF/NFATC3_DYSF/SNRPN_DYSF/POLR2J2_DYSF/CEP68_DYSF/CYLD_DYSF/NFATC3_FCAR/POLR2J2_FCAR/CEP68_FCAR/TXK_FCAR/RPP38_FCAR/NEFL_CREB5/KLF12_G0S2/PCM1_G0S2/ATF7IP_G0S2/REPS1_G0S2/INPP4B_G0S2/SNRPN_G0S2/TRAF3IP3_G0S2/NEFL_G0S2/POLR2J2_G0S2/CREBZF_G0S2/CEP68_G0S2/TXK_G0S2/MAP3K1_G0S2/RPP38_G0S2/FOXP1_FPR1/PSPC1_FPR1/INPP4B_FPR1/TRAF3IP3_FPR1/PCM1_PDE4B/PSPC1_PDE4B/CASP8_PDE4B/SNRPN_PDE4B/NEFL_PDE4B/CEP68_PDE4B/TXK_PDE4B/MAP3K1_PDE4B/RPP38_PDE4B/RPP38_LILRB2
# 282 MAOB_KRT13/MS4A2_KRT5/CPA3_KRT5/SIGLEC6_KRT5/MAOB_KRT5/HPGD_KRT5/MAOB_BMP4/MLPH_VSNL1/MAOB_VSNL1/PPM1H_ASPSCR1/MAOB_ASPSCR1/MAOB_IGF2/MAOB_MFAP2/MLPH_S100A2/ADCYAP1_S100A2/SLC24A3_S100A2/PRG2_S100A2/CTSG_S100A2/SLC18A2_S100A2/MS4A2_S100A2/CPA3_S100A2/TPSB2_S100A2/GATA2_S100A2/HDC_S100A2/SIGLEC6_S100A2/CMA1_S100A2/MPO_S100A2/NR0B1_S100A2/PPM1H_S100A2/KIT_S100A2/TAL1_S100A2/ABCC4_S100A2/PTGS1_S100A2/MAOB_S100A2/HPGD_S100A2/SCG2_S100A2/CEACAM8_S100A2/SIGLEC6_INHBB/PPM1H_INHBB/MAOB_INHBB/MLPH_JAG2/PPM1H_JAG2/MAOB_JAG2/MAOB_RPP25/MAOB_RHOD/CTSG_DHRS2/MAOB_DHRS2/MAOB_ITGB4/MAOB_STRA6/MAOB_SLC1A5/TPSB2_FKBP4/PPM1H_FKBP4/TAL1_FKBP4/MAOB_FKBP4/HPGD_FKBP4/MAOB_TEAD4/MAOB_SLC27A5/PPM1H_HOXA9/MAOB_HOXA9
# 191 BLK_ALPL/TNFRSF17_ALPL/HLA-DOB_ALPL/BACH2_ALPL/GNG7_ALPL/SCN3A_ALPL/BLNK_ALPL/IGHM_ALPL/BLNK_SIGLEC5/GNG7_CD93/SCN3A_CD93/BLNK_CD93/OSBPL10_MGAM/GLDC_MGAM/BLNK_CSF3R/MICAL3_MME/IGHA1_MME/ABCB4_MME/GNG7_MME/SCN3A_MME/SLC15A2_MME/BLNK_MME/GLDC_MME/GNG7_DYSF/CCR9_DYSF/SCN3A_DYSF/BLNK_DYSF/BLK_FCAR/BLNK_FCAR/CCR9_CEACAM3/BLNK_CEACAM3/BLNK_HPSE/BLNK_CREB5/BLNK_S100A12/BLNK_TNFRSF10C/CCR9_SLC25A37/MS4A1_G0S2/TCL1A_G0S2/BLK_G0S2/TNFRSF17_G0S2/ABCB4_G0S2/HLA-DOB_G0S2/CD19_G0S2/FAM30A_G0S2/SPIB_G0S2/BCL11A_G0S2/BACH2_G0S2/GNG7_G0S2/CCR9_G0S2/QRSL1_G0S2/DTNB_G0S2/SCN3A_G0S2/SLC15A2_G0S2/BLNK_G0S2/BLK_FPR1/GNG7_FPR1/SCN3A_FPR1/BLNK_FPR1/BLK_PDE4B/GNG7_PDE4B/CCR9_PDE4B/QRSL1_PDE4B/SCN3A_PDE4B/BLNK_PDE4B/COCH_LILRB2/CCR9_LILRB2/BLNK_LILRB2
# 321 CAT_FRYL/ACACB_FRYL/ABHD2_FRYL/SMPD3_FRYL/MYO15B_FRYL/ACACB_RPA1/ABHD2_RPA1/SMPD3_RPA1/MYO15B_RPA1/ABHD2_ICOS/KBTBD11_LRBA/SMPD3_LRBA/EPN2_LRBA/ACACB_NAP1L4/KBTBD11_NAP1L4/ABHD2_NAP1L4/SMPD3_NAP1L4/MYO15B_NAP1L4/THBS1_BATF/SMPD3_BATF/EPN2_BATF/THBS1_ASF1A/KBTBD11_ASF1A/SMPD3_ASF1A/KBTBD11_GOLGA8A/SMPD3_GOLGA8A/TKTL1_ANP32B/CAT_ANP32B/ACACB_ANP32B/RCOR3_ANP32B/SYNJ1_ANP32B/ABHD2_ANP32B/SMPD3_ANP32B/MYO15B_ANP32B/CAT_DDX50/ACACB_DDX50/KBTBD11_DDX50/ABHD2_DDX50/SMPD3_DDX50/KBTBD11_UBE2L3/ABHD2_UBE2L3/SMPD3_UBE2L3/IL5RA_SLC25A12/CAT_SLC25A12/ACACB_SLC25A12/GALC_SLC25A12/KBTBD11_SLC25A12/ABHD2_SLC25A12/SMPD3_SLC25A12/MYO15B_SLC25A12/HRH4_ATF2/CAT_ATF2/ACACB_ATF2/KBTBD11_ATF2/ABHD2_ATF2/SMPD3_ATF2/MYO15B_ATF2/SMPD3_CD28/CAT_PPP2R5C/ACACB_PPP2R5C/KBTBD11_PPP2R5C/SMPD3_PPP2R5C/ACACB_NUP107/KBTBD11_NUP107/ABHD2_NUP107/SMPD3_NUP107/MYO15B_NUP107/ACACB_SEC24C/ABHD2_SEC24C/SMPD3_SEC24C/SMPD3_FAM111A/CAT_PHF10/KBTBD11_PHF10/ABHD2_PHF10/SMPD3_PHF10

# %% [markdown]
# Cinstruct Circus plot for cell interactions and save in pdf, tiff and svg format

# %%
# Define A4 dimensions in inches
a4_width <- 8.27
a4_height <- 11.69

# Function to export TimiCellChord to various formats
export_timicellchord <- function(filename, width, height, res = 300, ...) {
  # Determine file format based on extension
  format <- tools::file_ext(filename)

  # Open appropriate device based on format
  switch(format,
         "pdf" = pdf(filename, width = width, height = height),
         "tiff" = tiff(filename, width = width, height = height, units = "in", res = res),
         "svg" = svg(filename, width = width, height = height),
         stop("Unsupported file format. Use pdf, tiff, or svg."))

  # Create the plot directly to the device
  TimiCellChord(...)

  # Close the device
  dev.off()

  print(paste("TimiCellChord plot saved to", filename))
}

# Export TimiCellChord plot to PDF, TIFF, and SVG (Portrait)
for (format in c("pdf", "tiff", "svg")) {
  export_timicellchord(
    paste0("TimiCellChord_A4_portrait_Top5percent.", format),
    a4_width,
    a4_height,
    resdata = res,
    select = NULL,
    dataset = "Bindea2013_Cancer",
    group = NULL,
    color = NULL,
    condition = CIcondition,
    cutoff = CIcutoff
  )
}

# Export TimiCellChord plot to PDF, TIFF, and SVG (Landscape)
for (format in c("pdf", "tiff", "svg")) {
  export_timicellchord(
    paste0("TimiCellChord_A4_landscape_Top5percent.", format),
    a4_height,
    a4_width,
    resdata = res,
    select = NULL,
    dataset = "Bindea2013_Cancer",
    group = NULL,
    color = NULL,
    condition = CIcondition,
    cutoff = CIcutoff
  )
}
# Out:
# Using cell-cell interactions(Adjust.P.Value < 0.05)
# [1] "TimiCellChord plot saved to TimiCellChord_A4_portrait_Top5percent.pdf"
# Using cell-cell interactions(Adjust.P.Value < 0.05)
# [1] "TimiCellChord plot saved to TimiCellChord_A4_portrait_Top5percent.tiff"
# Using cell-cell interactions(Adjust.P.Value < 0.05)
# [1] "TimiCellChord plot saved to TimiCellChord_A4_portrait_Top5percent.svg"
# Using cell-cell interactions(Adjust.P.Value < 0.05)
# [1] "TimiCellChord plot saved to TimiCellChord_A4_landscape_Top5percent.pdf"
# Using cell-cell interactions(Adjust.P.Value < 0.05)
# [1] "TimiCellChord plot saved to TimiCellChord_A4_landscape_Top5percent.tiff"
# Using cell-cell interactions(Adjust.P.Value < 0.05)
# [1] "TimiCellChord plot saved to TimiCellChord_A4_landscape_Top5percent.svg"

# %% [markdown]
# Construct Circus plots for top 5 cell interactions and save in tiff and svg format.

# %%
# `select` the cell-cell interaction #3 according to the index

# Default `color`

TimiGeneChord(resdata = res,select = 3, color = NULL)

# Save as SVG
svg("cell_cell_interaction_1_Top5percent.svg", width = 10, height = 10)
TimiGeneChord(resdata = res, select = 1, color = NULL)
dev.off()

# Save as TIFF with 300 dpi
tiff("cell_cell_interaction_1_Top5percent.tiff", width = 10, height = 10, units = "in", res = 300)
TimiGeneChord(resdata = res, select = 1, color = NULL)
dev.off()

# Save as SVG
svg("cell_cell_interaction_2_Top5percent.svg", width = 10, height = 10)
TimiGeneChord(resdata = res, select = 2, color = NULL)
dev.off()

# Save as TIFF with 300 dpi
tiff("cell_cell_interaction_2_Top5percent.tiff", width = 10, height = 10, units = "in", res = 300)
TimiGeneChord(resdata = res, select = 2, color = NULL)
dev.off()

# Save as SVG
svg("cell_cell_interaction_3_Top5percent.svg", width = 10, height = 10)
TimiGeneChord(resdata = res, select = 3, color = NULL)
dev.off()

# Save as TIFF with 300 dpi
tiff("cell_cell_interaction_3_Top5percent.tiff", width = 10, height = 10, units = "in", res = 300)
TimiGeneChord(resdata = res, select = 3, color = NULL)
dev.off()

# Save as SVG
svg("cell_cell_interaction_4_Top5percent.svg", width = 10, height = 10)
TimiGeneChord(resdata = res, select = 4, color = NULL)
dev.off()

# Save as TIFF with 300 dpi
tiff("cell_cell_interaction_4_Top5percent.tiff", width = 10, height = 10, units = "in", res = 300)
TimiGeneChord(resdata = res, select = 4, color = NULL)
dev.off()

# Save as SVG
svg("cell_cell_interaction_5_Top5percent.svg", width = 10, height = 10)
TimiGeneChord(resdata = res, select = 5, color = NULL)
dev.off()

# Save as TIFF with 300 dpi
tiff("cell_cell_interaction_5_Top5percent.tiff", width = 10, height = 10, units = "in", res = 300)
TimiGeneChord(resdata = res, select = 5, color = NULL)
dev.off()
# Out:
# Using default color
#
# Using default color
# pdf
#   2
# Using default color
# pdf
#   2
# Using default color
# pdf
#   2
# Using default color
# pdf
#   2
# Using default color
# pdf
#   2
# Using default color
# pdf
#   2
# Using default color
# pdf
#   2
# Using default color
# pdf
#   2
# Using default color
# pdf
#   2
# Using default color
# pdf
#   2
# Plot with title “Tcm_Neutrophil(Adjusted P-Value < 0.001)”

# %%
# Run TimiFS
score <- TimiFS(resdata = res,
                condition = CIcondition,
                cutoff = CIcutoff)
write.csv(score, file = 'score.csv')

# Visualize favorability scores for selected cell types,

# including the top 5 and bottom 3 cell types.

TimiFSBar(score, select = c(1:5, (nrow(score) - 2):nrow(score)))

# Save as SVG
svg("TimiFSBar_output_Top5percent.svg", width = 12, height = 8)
TimiFSBar(score, select = c(1:5, (nrow(score) - 2):nrow(score)))
dev.off()

# Save as TIFF with 300 dpi
tiff("TimiFSBar_output_Top5percent.tiff", width = 12, height = 8, units = "in", res = 300)
TimiFSBar(score, select = c(1:5, (nrow(score) - 2):nrow(score)))
dev.off()
# Out:
# Using cell-cell interactions(Adjust.P.Value < 0.05)
# pdf
#   2
# pdf
#   2
# plot without title

# %%
# Define A4 dimensions in inches
a4_width <- 8.27
a4_height <- 11.69

# Function to export TimiCellChord to various formats
export_timicellchord <- function(filename, width, height, res = 300, ...) {
  # Determine file format based on extension
  format <- tools::file_ext(filename)

  # Open appropriate device based on format
  switch(format,
         "pdf" = pdf(filename, width = width, height = height),
         "tiff" = tiff(filename, width = width, height = height, units = "in", res = res),
         "svg" = svg(filename, width = width, height = height),
         stop("Unsupported file format. Use pdf, tiff, or svg."))

  # Create the plot directly to the device
  TimiCellChord(...)

  # Close the device
  dev.off()

  print(paste("TimiCellChord plot saved to", filename))
}

# Export TimiCellChord plot to PDF, TIFF, and SVG (Portrait)
for (format in c("pdf", "tiff", "svg")) {
  export_timicellchord(
    paste0("TimiCellChord_A4_portrait_Top5percent.", format),
    a4_height,
    a4_width,
    resdata = res,
    select = NULL,
    dataset = "Bindea2013_Cancer",
    group = NULL,
    color = NULL,
    condition = CIcondition,
    cutoff = CIcutoff
  )
}

# Export TimiCellChord plot to PDF, TIFF, and SVG (Landscape)
for (format in c("pdf", "tiff", "svg")) {
  export_timicellchord(
    paste0("TimiCellChord_A4_landscape_Top5percent.", format),
    a4_height,
    a4_width,
    resdata = res,
    select = NULL,
    dataset = "Bindea2013_Cancer",
    group = NULL,
    color = NULL,
    condition = CIcondition,
    cutoff = CIcutoff
  )
}
# Out:
# Using cell-cell interactions(Adjust.P.Value < 0.05)
# [1] "TimiCellChord plot saved to TimiCellChord_A4_portrait_Top5percent.pdf"
# Using cell-cell interactions(Adjust.P.Value < 0.05)
# [1] "TimiCellChord plot saved to TimiCellChord_A4_portrait_Top5percent.tiff"
# Using cell-cell interactions(Adjust.P.Value < 0.05)
# [1] "TimiCellChord plot saved to TimiCellChord_A4_portrait_Top5percent.svg"
# Using cell-cell interactions(Adjust.P.Value < 0.05)
# [1] "TimiCellChord plot saved to TimiCellChord_A4_landscape_Top5percent.pdf"
# Using cell-cell interactions(Adjust.P.Value < 0.05)
# [1] "TimiCellChord plot saved to TimiCellChord_A4_landscape_Top5percent.tiff"
# Using cell-cell interactions(Adjust.P.Value < 0.05)
# [1] "TimiCellChord plot saved to TimiCellChord_A4_landscape_Top5percent.svg"

# %% [markdown]
# # Save everything as R session

# %%
# Save the entire workspace to a file named 'workspace.RData'
save.image(file = "timi_normla_weight_Bindea2013.RData")
